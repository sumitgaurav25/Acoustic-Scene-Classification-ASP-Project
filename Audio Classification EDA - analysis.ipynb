# %%
pip install librosa
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip install Ipython

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
filename = 'E:\\Users\\Sumit\\Downloads\\UrbanSound8K\\UrbanSound8K\\bang.wav'

# %%
import IPython.display as ipd
import librosa
import librosa.display

# %%
###banging sound as an example

plt.figure(figsize = (14,5))
data,sample_rate = librosa.load(filename)
librosa.display.waveshow(data, sr = sample_rate)
ipd.Audio(filename)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
sample_rate
# Out:
# 22050

# %%
from scipy.io import wavfile as wav
wave_sample_rate, wave_audio = wav.read(filename)

# %%
wave_sample_rate
# Out:
# 44100

# %%
wave_audio
# Out:
# array([[-4334, -2477],
#        [-4355, -2096],
#        [-3778, -1386],
#        ...,
#        [-7741, -5015],
#        [-7692, -5511],
#        [-5315, -4305]], dtype=int16)

# %%
data
# Out:
# array([-0.07676625, -0.08617157,  0.00135402, ...,  0.06153922,
#        -0.12869518, -0.20135155], dtype=float32)

# %%
### Exploring and Analysing the Dataset(labelled dataset)

# %%
import pandas as pd

metadata=pd.read_csv('E:\\Users\\Sumit\\Downloads\\UrbanSound8K\\UrbanSound8K\\metadata\\UrbanSound8K.csv')
metadata.head(10)
# Out:
#       slice_file_name    fsID      start        end  salience  fold  classID  \
# 0    100032-3-0-0.wav  100032   0.000000   0.317551         1     5        3
# 1  100263-2-0-117.wav  100263  58.500000  62.500000         1     5        2
# 2  100263-2-0-121.wav  100263  60.500000  64.500000         1     5        2
# 3  100263-2-0-126.wav  100263  63.000000  67.000000         1     5        2
# 4  100263-2-0-137.wav  100263  68.500000  72.500000         1     5        2
# 5  100263-2-0-143.wav  100263  71.500000  75.500000         1     5        2
# 6  100263-2-0-161.wav  100263  80.500000  84.500000         1     5        2
# 7    100263-2-0-3.wav  100263   1.500000   5.500000         1     5        2
# 8   100263-2-0-36.wav  100263  18.000000  22.000000         1     5        2
# 9    100648-1-0-0.wav  100648   4.823402   5.471927         2    10        1
#
#               class
# 0          dog_bark
# 1  children_playing
# 2  children_playing
# 3  children_playing
# ...

# %%
### check whether the dataset is imbalanced

metadata['class'].value_counts()
# Out:
# class
# dog_bark            1000
# children_playing    1000
# air_conditioner     1000
# street_music        1000
# engine_idling       1000
# jackhammer          1000
# drilling            1000
# siren                929
# car_horn             429
# gun_shot             374
# Name: count, dtype: int64

# %%
### hence from the above table of class of dataset we can observe that most of the categories are having almost equal 
### number of data values so this is not a unbalanced dataset.
